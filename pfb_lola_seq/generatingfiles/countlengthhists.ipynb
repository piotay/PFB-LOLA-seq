# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/Users/pfb2024/Downloads/MA8_genome_cov_bg.txt',sep='\t',header=None)

# %%
data
# Out:
#               0         1         2  3
# 0          chr1     10067     10078  2
# 1          chr1     10078     10079  3
# 2          chr1     10079     10084  5
# 3          chr1     10084     10085  7
# 4          chr1     10085     10090  9
# ...         ...       ...       ... ..
# 275975718  chrY  56887417  56887454  5
# 275975719  chrY  56887454  56887463  6
# 275975720  chrY  56887463  56887496  5
# 275975721  chrY  56887496  56887499  2
# 275975722  chrY  56887499  56887839  1
#
# [275975723 rows x 4 columns]

# %%
newdepth={}
with open('/Users/pfb2024/Downloads/MA8_genome_cov_bg.txt','r') as genomecor:
    for line in genomecor:
        line=line.rstrip()
        values=line.split('\t')
        if int(values[3]) in newdepth:
            newdepth[int(values[3])]+=int(values[2])-int(values[1])
        else:
            newdepth[int(values[3])]=int(values[2])-int(values[1])
newdepths=pd.DataFrame(newdepth.items())
sortednewdepths=newdepths.sort_values(by=0)
sortedstink
# Out:
#           0          1
# 40        1   41797504
# 0         2   56502117
# 1         3   81717387
# 39        4  111414077
# 2         5  140493338
# ...     ...        ...
# 2273  58713          1
# 2272  58730          1
# 2271  58739          1
# 2269  58763          1
# 2270  58769          1
#
# [2632 rows x 2 columns]

# %%
sortedstink.plot.bar(x=0,y=1)
plt.xticks(rotation=45)
# Out:
# (array([   0,    1,    2, ..., 2629, 2630, 2631]),
#  [Text(0, 0, '1'),
#   Text(1, 0, '2'),
#   Text(2, 0, '3'),
#   Text(3, 0, '4'),
#   Text(4, 0, '5'),
#   Text(5, 0, '6'),
#   Text(6, 0, '7'),
#   Text(7, 0, '8'),
#   Text(8, 0, '9'),
#   Text(9, 0, '10'),
#   Text(10, 0, '11'),
#   Text(11, 0, '12'),
#   Text(12, 0, '13'),
#   Text(13, 0, '14'),
#   Text(14, 0, '15'),
#   Text(15, 0, '16'),
#   Text(16, 0, '17'),
#   Text(17, 0, '18'),
#   Text(18, 0, '19'),
#   Text(19, 0, '20'),
#   Text(20, 0, '21'),
#   Text(21, 0, '22'),
#   Text(22, 0, '23'),
#   Text(23, 0, '24'),
#   Text(24, 0, '25'),
#   Text(25, 0, '26'),
#   Text(26, 0, '27'),
#   Text(27, 0, '28'),
#   Text(28, 0, '29'),
#   Text(29, 0, '30'),
#   Text(30, 0, '31'),
#   Text(31, 0, '32'),
#   Text(32, 0, '33'),
#   Text(33, 0, '34'),
#   Text(34, 0, '35'),
#   Text(35, 0, '36'),
#   Text(36, 0, '37'),
#   Text(37, 0, '38'),
#   Text(38, 0, '39'),
#   Text(39, 0, '40'),
#   Text(40, 0, '41'),
#   Text(41, 0, '42'),
#   Text(42, 0, '43'),
#   Text(43, 0, '44'),
#   Text(44, 0, '45'),
#   Text(45, 0, '46'),
#   Text(46, 0, '47'),
#   Text(47, 0, '48'),
#   Text(48, 0, '49'),
#   Text(49, 0, '50'),
#   Text(50, 0, '51'),
#   Text(51, 0, '52'),
#   Text(52, 0, '53'),
#   Text(53, 0, '54'),
#   Text(54, 0, '55'),
#   Text(55, 0, '56'),
#   Text(56, 0, '57'),
#   Text(57, 0, '58'),
#   Text(58, 0, '59'),
#   Text(59, 0, '60'),
#   Text(60, 0, '61'),
#   Text(61, 0, '62'),
#   Text(62, 0, '63'),
#   Text(63, 0, '64'),
#   Text(64, 0, '65'),
#   Text(65, 0, '66'),
#   Text(66, 0, '67'),
#   Text(67, 0, '68'),
#   Text(68, 0, '69'),
#   Text(69, 0, '70'),
#   Text(70, 0, '71'),
#   Text(71, 0, '72'),
#   Text(72, 0, '73'),
#   Text(73, 0, '74'),
#   Text(74, 0, '75'),
#   Text(75, 0, '76'),
#   Text(76, 0, '77'),
#   Text(77, 0, '78'),
#   Text(78, 0, '79'),
#   Text(79, 0, '80'),
#   Text(80, 0, '81'),
#   Text(81, 0, '82'),
#   Text(82, 0, '83'),
#   Text(83, 0, '84'),
#   Text(84, 0, '85'),
#   Text(85, 0, '86'),
#   Text(86, 0, '87'),
#   Text(87, 0, '88'),
#   Text(88, 0, '89'),
#   Text(89, 0, '90'),
#   Text(90, 0, '91'),
#   Text(91, 0, '92'),
#   Text(92, 0, '93'),
#   Text(93, 0, '94'),
#   Text(94, 0, '95'),
#   Text(95, 0, '96'),
#   Text(96, 0, '97'),
#   Text(97, 0, '98'),
#   Text(98, 0, '99'),
#   Text(99, 0, '100'),
#   Text(100, 0, '101'),
#   Text(101, 0, '102'),
#   Text(102, 0, '103'),
#   Text(103, 0, '104'),
#   Text(104, 0, '105'),
#   Text(105, 0, '106'),
#   Text(106, 0, '107'),
#   Text(107, 0, '108'),
#   Text(108, 0, '109'),
#   Text(109, 0, '110'),
#   Text(110, 0, '111'),
#   Text(111, 0, '112'),
#   Text(112, 0, '113'),
#   Text(113, 0, '114'),
#   Text(114, 0, '115'),
#   Text(115, 0, '116'),
#   Text(116, 0, '117'),
#   Text(117, 0, '118'),
#   Text(118, 0, '119'),
#   Text(119, 0, '120'),
#   Text(120, 0, '121'),
#   Text(121, 0, '122'),
#   Text(122, 0, '123'),
#   Text(123, 0, '124'),
#   Text(124, 0, '125'),
#   Text(125, 0, '126'),
#   Text(126, 0, '127'),
#   Text(127, 0, '128'),
#   Text(128, 0, '129'),
#   Text(129, 0, '130'),
#   Text(130, 0, '131'),
#   Text(131, 0, '132'),
#   Text(132, 0, '133'),
#   Text(133, 0, '134'),
#   Text(134, 0, '135'),
#   Text(135, 0, '136'),
#   Text(136, 0, '137'),
#   Text(137, 0, '138'),
#   Text(138, 0, '139'),
#   Text(139, 0, '140'),
#   Text(140, 0, '141'),
#   Text(141, 0, '142'),
#   Text(142, 0, '143'),
#   Text(143, 0, '144'),
#   Text(144, 0, '145'),
#   Text(145, 0, '146'),
#   Text(146, 0, '147'),
#   Text(147, 0, '148'),
#   Text(148, 0, '149'),
#   Text(149, 0, '150'),
#   Text(150, 0, '151'),
#   Text(151, 0, '152'),
#   Text(152, 0, '153'),
#   Text(153, 0, '154'),
#   Text(154, 0, '155'),
#   Text(155, 0, '156'),
#   Text(156, 0, '157'),
#   Text(157, 0, '158'),
#   Text(158, 0, '159'),
#   Text(159, 0, '160'),
#   Text(160, 0, '161'),
#   Text(161, 0, '162'),
#   Text(162, 0, '163'),
#   Text(163, 0, '164'),
#   Text(164, 0, '165'),
#   Text(165, 0, '166'),
#   Text(166, 0, '167'),
#   Text(167, 0, '168'),
#   Text(168, 0, '169'),
#   Text(169, 0, '170'),
#   Text(170, 0, '171'),
#   Text(171, 0, '172'),
#   Text(172, 0, '173'),
#   Text(173, 0, '174'),
#   Text(174, 0, '175'),
#   Text(175, 0, '176'),
#   Text(176, 0, '177'),
#   Text(177, 0, '178'),
#   Text(178, 0, '179'),
#   Text(179, 0, '180'),
#   Text(180, 0, '181'),
#   Text(181, 0, '182'),
#   Text(182, 0, '183'),
#   Text(183, 0, '184'),
#   Text(184, 0, '185'),
#   Text(185, 0, '186'),
#   Text(186, 0, '187'),
#   Text(187, 0, '188'),
#   Text(188, 0, '189'),
#   Text(189, 0, '190'),
#   Text(190, 0, '191'),
#   Text(191, 0, '192'),
#   Text(192, 0, '193'),
#   Text(193, 0, '194'),
#   Text(194, 0, '195'),
#   Text(195, 0, '196'),
#   Text(196, 0, '197'),
#   Text(197, 0, '198'),
#   Text(198, 0, '199'),
#   Text(199, 0, '200'),
#   Text(200, 0, '201'),
#   Text(201, 0, '202'),
#   Text(202, 0, '203'),
#   Text(203, 0, '204'),
#   Text(204, 0, '205'),
#   Text(205, 0, '206'),
#   Text(206, 0, '207'),
#   Text(207, 0, '208'),
#   Text(208, 0, '209'),
#   Text(209, 0, '210'),
#   Text(210, 0, '211'),
#   Text(211, 0, '212'),
#   Text(212, 0, '213'),
#   Text(213, 0, '214'),
#   Text(214, 0, '215'),
#   Text(215, 0, '216'),
#   Text(216, 0, '217'),
#   Text(217, 0, '218'),
#   Text(218, 0, '219'),
#   Text(219, 0, '220'),
#   Text(220, 0, '221'),
#   Text(221, 0, '222'),
#   Text(222, 0, '223'),
#   Text(223, 0, '224'),
#   Text(224, 0, '225'),
#   Text(225, 0, '226'),
#   Text(226, 0, '227'),
#   Text(227, 0, '228'),
#   Text(228, 0, '229'),
#   Text(229, 0, '230'),
#   Text(230, 0, '231'),
#   Text(231, 0, '232'),
#   Text(232, 0, '233'),
#   Text(233, 0, '234'),
#   Text(234, 0, '235'),
#   Text(235, 0, '236'),
#   Text(236, 0, '237'),
#   Text(237, 0, '238'),
#   Text(238, 0, '239'),
#   Text(239, 0, '240'),
#   Text(240, 0, '241'),
#   Text(241, 0, '242'),
#   Text(242, 0, '243'),
#   Text(243, 0, '244'),
#   Text(244, 0, '245'),
#   Text(245, 0, '246'),
#   Text(246, 0, '247'),
#   Text(247, 0, '248'),
#   Text(248, 0, '249'),
#   Text(249, 0, '250'),
#   Text(250, 0, '251'),
#   Text(251, 0, '252'),
#   Text(252, 0, '253'),
#   Text(253, 0, '254'),
#   Text(254, 0, '255'),
#   Text(255, 0, '256'),
#   Text(256, 0, '257'),
#   Text(257, 0, '258'),
#   Text(258, 0, '259'),
#   Text(259, 0, '260'),
#   Text(260, 0, '261'),
#   Text(261, 0, '262'),
#   Text(262, 0, '263'),
#   Text(263, 0, '264'),
#   Text(264, 0, '265'),
#   Text(265, 0, '266'),
#   Text(266, 0, '267'),
#   Text(267, 0, '268'),
#   Text(268, 0, '269'),
#   Text(269, 0, '270'),
#   Text(270, 0, '271'),
#   Text(271, 0, '272'),
#   Text(272, 0, '273'),
#   Text(273, 0, '274'),
#   Text(274, 0, '275'),
#   Text(275, 0, '276'),
#   Text(276, 0, '277'),
#   Text(277, 0, '278'),
#   Text(278, 0, '279'),
#   Text(279, 0, '280'),
#   Text(280, 0, '281'),
#   Text(281, 0, '282'),
#   Text(282, 0, '283'),
#   Text(283, 0, '284'),
#   Text(284, 0, '285'),
#   Text(285, 0, '286'),
#   Text(286, 0, '287'),
#   Text(287, 0, '288'),
#   Text(288, 0, '289'),
#   Text(289, 0, '290'),
#   Text(290, 0, '291'),
#   Text(291, 0, '292'),
#   Text(292, 0, '293'),
#   Text(293, 0, '294'),
#   Text(294, 0, '295'),
#   Text(295, 0, '296'),
#   Text(296, 0, '297'),
#   Text(297, 0, '298'),
#   Text(298, 0, '299'),
#   Text(299, 0, '300'),
#   Text(300, 0, '301'),
#   Text(301, 0, '302'),
#   Text(302, 0, '303'),
#   Text(303, 0, '304'),
#   Text(304, 0, '305'),
#   Text(305, 0, '306'),
#   Text(306, 0, '307'),
#   Text(307, 0, '308'),
#   Text(308, 0, '309'),
#   Text(309, 0, '310'),
#   Text(310, 0, '311'),
#   Text(311, 0, '312'),
#   Text(312, 0, '313'),
#   Text(313, 0, '314'),
#   Text(314, 0, '315'),
#   Text(315, 0, '316'),
#   Text(316, 0, '317'),
#   Text(317, 0, '318'),
#   Text(318, 0, '319'),
#   Text(319, 0, '320'),
#   Text(320, 0, '321'),
#   Text(321, 0, '322'),
#   Text(322, 0, '323'),
#   Text(323, 0, '324'),
#   Text(324, 0, '325'),
#   Text(325, 0, '326'),
#   Text(326, 0, '327'),
#   Text(327, 0, '328'),
#   Text(328, 0, '329'),
#   Text(329, 0, '330'),
#   Text(330, 0, '331'),
#   Text(331, 0, '332'),
#   Text(332, 0, '333'),
#   Text(333, 0, '334'),
#   Text(334, 0, '335'),
#   Text(335, 0, '336'),
#   Text(336, 0, '337'),
#   Text(337, 0, '338'),
#   Text(338, 0, '339'),
#   Text(339, 0, '340'),
#   Text(340, 0, '341'),
#   Text(341, 0, '342'),
#   Text(342, 0, '343'),
#   Text(343, 0, '344'),
#   Text(344, 0, '345'),
#   Text(345, 0, '346'),
#   Text(346, 0, '347'),
#   Text(347, 0, '348'),
#   Text(348, 0, '349'),
#   Text(349, 0, '350'),
#   Text(350, 0, '351'),
#   Text(351, 0, '352'),
#   Text(352, 0, '353'),
#   Text(353, 0, '354'),
#   Text(354, 0, '355'),
#   Text(355, 0, '356'),
#   Text(356, 0, '357'),
#   Text(357, 0, '358'),
#   Text(358, 0, '359'),
#   Text(359, 0, '360'),
#   Text(360, 0, '361'),
#   Text(361, 0, '362'),
#   Text(362, 0, '363'),
#   Text(363, 0, '364'),
#   Text(364, 0, '365'),
#   Text(365, 0, '366'),
#   Text(366, 0, '367'),
#   Text(367, 0, '368'),
#   Text(368, 0, '369'),
#   Text(369, 0, '370'),
#   Text(370, 0, '371'),
#   Text(371, 0, '372'),
#   Text(372, 0, '373'),
#   Text(373, 0, '374'),
#   Text(374, 0, '375'),
#   Text(375, 0, '376'),
#   Text(376, 0, '377'),
#   Text(377, 0, '378'),
#   Text(378, 0, '379'),
#   Text(379, 0, '380'),
#   Text(380, 0, '381'),
#   Text(381, 0, '382'),
#   Text(382, 0, '383'),
#   Text(383, 0, '384'),
#   Text(384, 0, '385'),
#   Text(385, 0, '386'),
#   Text(386, 0, '387'),
#   Text(387, 0, '388'),
#   Text(388, 0, '389'),
#   Text(389, 0, '390'),
#   Text(390, 0, '391'),
#   Text(391, 0, '392'),
#   Text(392, 0, '393'),
#   Text(393, 0, '394'),
#   Text(394, 0, '395'),
#   Text(395, 0, '396'),
#   Text(396, 0, '397'),
#   Text(397, 0, '398'),
#   Text(398, 0, '399'),
#   Text(399, 0, '400'),
#   Text(400, 0, '401'),
#   Text(401, 0, '402'),
#   Text(402, 0, '403'),
#   Text(403, 0, '404'),
#   Text(404, 0, '405'),
#   Text(405, 0, '406'),
#   Text(406, 0, '407'),
#   Text(407, 0, '408'),
#   Text(408, 0, '409'),
#   Text(409, 0, '410'),
#   Text(410, 0, '411'),
#   Text(411, 0, '412'),
#   Text(412, 0, '413'),
#   Text(413, 0, '414'),
#   Text(414, 0, '415'),
#   Text(415, 0, '416'),
#   Text(416, 0, '417'),
#   Text(417, 0, '418'),
#   Text(418, 0, '419'),
#   Text(419, 0, '420'),
#   Text(420, 0, '421'),
#   Text(421, 0, '422'),
#   Text(422, 0, '423'),
#   Text(423, 0, '424'),
#   Text(424, 0, '425'),
#   Text(425, 0, '426'),
#   Text(426, 0, '427'),
#   Text(427, 0, '428'),
#   Text(428, 0, '429'),
#   Text(429, 0, '430'),
#   Text(430, 0, '431'),
#   Text(431, 0, '432'),
#   Text(432, 0, '433'),
#   Text(433, 0, '434'),
#   Text(434, 0, '435'),
#   Text(435, 0, '436'),
#   Text(436, 0, '437'),
#   Text(437, 0, '438'),
#   Text(438, 0, '439'),
#   Text(439, 0, '440'),
#   Text(440, 0, '441'),
#   Text(441, 0, '442'),
#   Text(442, 0, '443'),
#   Text(443, 0, '444'),
#   Text(444, 0, '445'),
#   Text(445, 0, '446'),
#   Text(446, 0, '447'),
#   Text(447, 0, '448'),
#   Text(448, 0, '449'),
#   Text(449, 0, '450'),
#   Text(450, 0, '451'),
#   Text(451, 0, '452'),
#   Text(452, 0, '453'),
#   Text(453, 0, '454'),
#   Text(454, 0, '455'),
#   Text(455, 0, '456'),
#   Text(456, 0, '457'),
#   Text(457, 0, '458'),
#   Text(458, 0, '459'),
#   Text(459, 0, '460'),
#   Text(460, 0, '461'),
#   Text(461, 0, '462'),
#   Text(462, 0, '463'),
#   Text(463, 0, '464'),
#   Text(464, 0, '465'),
#   Text(465, 0, '466'),
#   Text(466, 0, '467'),
#   Text(467, 0, '468'),
#   Text(468, 0, '469'),
#   Text(469, 0, '470'),
#   Text(470, 0, '471'),
#   Text(471, 0, '472'),
#   Text(472, 0, '473'),
#   Text(473, 0, '474'),
#   Text(474, 0, '475'),
#   Text(475, 0, '476'),
#   Text(476, 0, '477'),
#   Text(477, 0, '478'),
#   Text(478, 0, '479'),
#   Text(479, 0, '480'),
#   Text(480, 0, '481'),
#   Text(481, 0, '482'),
#   Text(482, 0, '483'),
#   Text(483, 0, '484'),
#   Text(484, 0, '485'),
#   Text(485, 0, '486'),
#   Text(486, 0, '487'),
#   Text(487, 0, '488'),
#   Text(488, 0, '489'),
#   Text(489, 0, '490'),
#   Text(490, 0, '491'),
#   Text(491, 0, '492'),
#   Text(492, 0, '493'),
#   Text(493, 0, '494'),
#   Text(494, 0, '495'),
#   Text(495, 0, '496'),
#   Text(496, 0, '497'),
#   Text(497, 0, '498'),
#   Text(498, 0, '499'),
#   Text(499, 0, '500'),
#   Text(500, 0, '501'),
#   Text(501, 0, '502'),
#   Text(502, 0, '503'),
#   Text(503, 0, '504'),
#   Text(504, 0, '505'),
#   Text(505, 0, '506'),
#   Text(506, 0, '507'),
#   Text(507, 0, '508'),
#   Text(508, 0, '509'),
#   Text(509, 0, '510'),
#   Text(510, 0, '511'),
#   Text(511, 0, '512'),
#   Text(512, 0, '513'),
#   Text(513, 0, '514'),
#   Text(514, 0, '515'),
#   Text(515, 0, '516'),
#   Text(516, 0, '517'),
#   Text(517, 0, '518'),
#   Text(518, 0, '519'),
#   Text(519, 0, '520'),
#   Text(520, 0, '521'),
#   Text(521, 0, '522'),
#   Text(522, 0, '523'),
#   Text(523, 0, '524'),
#   Text(524, 0, '525'),
#   Text(525, 0, '526'),
#   Text(526, 0, '527'),
#   Text(527, 0, '528'),
#   Text(528, 0, '529'),
#   Text(529, 0, '530'),
#   Text(530, 0, '531'),
#   Text(531, 0, '532'),
#   Text(532, 0, '533'),
#   Text(533, 0, '534'),
#   Text(534, 0, '535'),
#   Text(535, 0, '536'),
#   Text(536, 0, '537'),
#   Text(537, 0, '538'),
#   Text(538, 0, '539'),
#   Text(539, 0, '540'),
#   Text(540, 0, '541'),
#   Text(541, 0, '542'),
#   Text(542, 0, '543'),
#   Text(543, 0, '544'),
#   Text(544, 0, '545'),
#   Text(545, 0, '546'),
#   Text(546, 0, '547'),
#   Text(547, 0, '548'),
#   Text(548, 0, '549'),
#   Text(549, 0, '550'),
#   Text(550, 0, '551'),
#   Text(551, 0, '552'),
#   Text(552, 0, '553'),
#   Text(553, 0, '554'),
#   Text(554, 0, '555'),
#   Text(555, 0, '556'),
#   Text(556, 0, '557'),
#   Text(557, 0, '558'),
#   Text(558, 0, '559'),
#   Text(559, 0, '560'),
#   Text(560, 0, '561'),
#   Text(561, 0, '562'),
#   Text(562, 0, '563'),
#   Text(563, 0, '564'),
#   Text(564, 0, '565'),
#   Text(565, 0, '566'),
#   Text(566, 0, '567'),
#   Text(567, 0, '568'),
#   Text(568, 0, '569'),
#   Text(569, 0, '570'),
#   Text(570, 0, '571'),
#   Text(571, 0, '572'),
#   Text(572, 0, '573'),
#   Text(573, 0, '574'),
#   Text(574, 0, '575'),
#   Text(575, 0, '576'),
#   Text(576, 0, '577'),
#   Text(577, 0, '578'),
#   Text(578, 0, '579'),
#   Text(579, 0, '580'),
#   Text(580, 0, '581'),
#   Text(581, 0, '582'),
#   Text(582, 0, '583'),
#   Text(583, 0, '584'),
#   Text(584, 0, '585'),
#   Text(585, 0, '586'),
#   Text(586, 0, '587'),
#   Text(587, 0, '588'),
#   Text(588, 0, '589'),
#   Text(589, 0, '590'),
#   Text(590, 0, '591'),
#   Text(591, 0, '592'),
#   Text(592, 0, '593'),
#   Text(593, 0, '594'),
#   Text(594, 0, '595'),
#   Text(595, 0, '596'),
#   Text(596, 0, '597'),
#   Text(597, 0, '598'),
#   Text(598, 0, '599'),
#   Text(599, 0, '600'),
#   Text(600, 0, '601'),
#   Text(601, 0, '602'),
#   Text(602, 0, '603'),
#   Text(603, 0, '604'),
#   Text(604, 0, '605'),
#   Text(605, 0, '606'),
#   Text(606, 0, '607'),
#   Text(607, 0, '608'),
#   Text(608, 0, '609'),
#   Text(609, 0, '610'),
#   Text(610, 0, '611'),
#   Text(611, 0, '612'),
#   Text(612, 0, '613'),
#   Text(613, 0, '614'),
#   Text(614, 0, '615'),
#   Text(615, 0, '616'),
#   Text(616, 0, '617'),
#   Text(617, 0, '618'),
#   Text(618, 0, '619'),
#   Text(619, 0, '620'),
#   Text(620, 0, '621'),
#   Text(621, 0, '622'),
#   Text(622, 0, '623'),
#   Text(623, 0, '624'),
#   Text(624, 0, '625'),
#   Text(625, 0, '626'),
#   Text(626, 0, '627'),
#   Text(627, 0, '628'),
#   Text(628, 0, '629'),
#   Text(629, 0, '630'),
#   Text(630, 0, '631'),
#   Text(631, 0, '632'),
#   Text(632, 0, '633'),
#   Text(633, 0, '634'),
#   Text(634, 0, '635'),
#   Text(635, 0, '636'),
#   Text(636, 0, '637'),
#   Text(637, 0, '638'),
#   Text(638, 0, '639'),
#   Text(639, 0, '640'),
#   Text(640, 0, '641'),
#   Text(641, 0, '642'),
#   Text(642, 0, '643'),
#   Text(643, 0, '644'),
#   Text(644, 0, '645'),
#   Text(645, 0, '646'),
#   Text(646, 0, '647'),
#   Text(647, 0, '648'),
#   Text(648, 0, '649'),
#   Text(649, 0, '650'),
#   Text(650, 0, '651'),
#   Text(651, 0, '652'),
#   Text(652, 0, '653'),
#   Text(653, 0, '654'),
#   Text(654, 0, '655'),
#   Text(655, 0, '656'),
#   Text(656, 0, '657'),
#   Text(657, 0, '658'),
#   Text(658, 0, '659'),
#   Text(659, 0, '660'),
#   Text(660, 0, '661'),
#   Text(661, 0, '662'),
#   Text(662, 0, '663'),
#   Text(663, 0, '664'),
#   Text(664, 0, '665'),
#   Text(665, 0, '666'),
#   Text(666, 0, '667'),
#   Text(667, 0, '668'),
#   Text(668, 0, '669'),
#   Text(669, 0, '670'),
#   Text(670, 0, '671'),
#   Text(671, 0, '672'),
#   Text(672, 0, '673'),
#   Text(673, 0, '674'),
#   Text(674, 0, '675'),
#   Text(675, 0, '676'),
#   Text(676, 0, '677'),
#   Text(677, 0, '678'),
#   Text(678, 0, '679'),
#   Text(679, 0, '680'),
#   Text(680, 0, '681'),
#   Text(681, 0, '682'),
#   Text(682, 0, '683'),
#   Text(683, 0, '684'),
#   Text(684, 0, '685'),
#   Text(685, 0, '686'),
#   Text(686, 0, '687'),
#   Text(687, 0, '688'),
#   Text(688, 0, '689'),
#   Text(689, 0, '690'),
#   Text(690, 0, '691'),
#   Text(691, 0, '692'),
#   Text(692, 0, '693'),
#   Text(693, 0, '694'),
#   Text(694, 0, '695'),
#   Text(695, 0, '696'),
#   Text(696, 0, '697'),
#   Text(697, 0, '698'),
#   Text(698, 0, '699'),
#   Text(699, 0, '700'),
#   Text(700, 0, '701'),
#   Text(701, 0, '702'),
#   Text(702, 0, '703'),
#   Text(703, 0, '704'),
#   Text(704, 0, '705'),
#   Text(705, 0, '706'),
#   Text(706, 0, '707'),
#   Text(707, 0, '708'),
#   Text(708, 0, '709'),
#   Text(709, 0, '710'),
#   Text(710, 0, '711'),
#   Text(711, 0, '712'),
#   Text(712, 0, '713'),
#   Text(713, 0, '714'),
#   Text(714, 0, '715'),
#   Text(715, 0, '716'),
#   Text(716, 0, '717'),
#   Text(717, 0, '718'),
#   Text(718, 0, '719'),
#   Text(719, 0, '720'),
#   Text(720, 0, '721'),
#   Text(721, 0, '722'),
#   Text(722, 0, '723'),
#   Text(723, 0, '724'),
#   Text(724, 0, '725'),
#   Text(725, 0, '726'),
#   Text(726, 0, '727'),
#   Text(727, 0, '728'),
#   Text(728, 0, '729'),
#   Text(729, 0, '730'),
#   Text(730, 0, '731'),
#   Text(731, 0, '732'),
#   Text(732, 0, '733'),
#   Text(733, 0, '734'),
#   Text(734, 0, '735'),
#   Text(735, 0, '736'),
#   Text(736, 0, '737'),
#   Text(737, 0, '738'),
#   Text(738, 0, '739'),
#   Text(739, 0, '740'),
#   Text(740, 0, '741'),
#   Text(741, 0, '742'),
#   Text(742, 0, '743'),
#   Text(743, 0, '744'),
#   Text(744, 0, '745'),
#   Text(745, 0, '746'),
#   Text(746, 0, '747'),
#   Text(747, 0, '748'),
#   Text(748, 0, '749'),
#   Text(749, 0, '750'),
#   Text(750, 0, '751'),
#   Text(751, 0, '752'),
#   Text(752, 0, '753'),
#   Text(753, 0, '754'),
#   Text(754, 0, '755'),
#   Text(755, 0, '756'),
#   Text(756, 0, '757'),
#   Text(757, 0, '758'),
#   Text(758, 0, '759'),
#   Text(759, 0, '760'),
#   Text(760, 0, '761'),
#   Text(761, 0, '762'),
#   Text(762, 0, '763'),
#   Text(763, 0, '764'),
#   Text(764, 0, '765'),
#   Text(765, 0, '766'),
#   Text(766, 0, '767'),
#   Text(767, 0, '768'),
#   Text(768, 0, '769'),
#   Text(769, 0, '770'),
#   Text(770, 0, '771'),
#   Text(771, 0, '772'),
#   Text(772, 0, '773'),
#   Text(773, 0, '774'),
#   Text(774, 0, '775'),
#   Text(775, 0, '776'),
#   Text(776, 0, '777'),
#   Text(777, 0, '778'),
#   Text(778, 0, '779'),
#   Text(779, 0, '780'),
#   Text(780, 0, '781'),
#   Text(781, 0, '782'),
#   Text(782, 0, '783'),
#   Text(783, 0, '784'),
#   Text(784, 0, '785'),
#   Text(785, 0, '786'),
#   Text(786, 0, '787'),
#   Text(787, 0, '788'),
#   Text(788, 0, '789'),
#   Text(789, 0, '790'),
#   Text(790, 0, '791'),
#   Text(791, 0, '792'),
#   Text(792, 0, '793'),
#   Text(793, 0, '794'),
#   Text(794, 0, '795'),
#   Text(795, 0, '796'),
#   Text(796, 0, '797'),
#   Text(797, 0, '798'),
#   Text(798, 0, '799'),
#   Text(799, 0, '800'),
#   Text(800, 0, '801'),
#   Text(801, 0, '802'),
#   Text(802, 0, '803'),
#   Text(803, 0, '804'),
#   Text(804, 0, '805'),
#   Text(805, 0, '806'),
#   Text(806, 0, '807'),
#   Text(807, 0, '808'),
#   Text(808, 0, '809'),
#   Text(809, 0, '810'),
#   Text(810, 0, '811'),
#   Text(811, 0, '812'),
#   Text(812, 0, '813'),
#   Text(813, 0, '814'),
#   Text(814, 0, '815'),
#   Text(815, 0, '816'),
#   Text(816, 0, '817'),
#   Text(817, 0, '818'),
#   Text(818, 0, '819'),
#   Text(819, 0, '820'),
#   Text(820, 0, '821'),
#   Text(821, 0, '822'),
#   Text(822, 0, '823'),
#   Text(823, 0, '824'),
#   Text(824, 0, '825'),
#   Text(825, 0, '826'),
#   Text(826, 0, '827'),
#   Text(827, 0, '828'),
#   Text(828, 0, '829'),
#   Text(829, 0, '830'),
#   Text(830, 0, '831'),
#   Text(831, 0, '832'),
#   Text(832, 0, '833'),
#   Text(833, 0, '834'),
#   Text(834, 0, '835'),
#   Text(835, 0, '837'),
#   Text(836, 0, '838'),
#   Text(837, 0, '839'),
#   Text(838, 0, '840'),
#   Text(839, 0, '841'),
#   Text(840, 0, '842'),
#   Text(841, 0, '843'),
#   Text(842, 0, '844'),
#   Text(843, 0, '845'),
#   Text(844, 0, '846'),
#   Text(845, 0, '847'),
#   Text(846, 0, '848'),
#   Text(847, 0, '849'),
#   Text(848, 0, '851'),
#   Text(849, 0, '852'),
#   Text(850, 0, '853'),
#   Text(851, 0, '854'),
#   Text(852, 0, '855'),
#   Text(853, 0, '856'),
#   Text(854, 0, '857'),
#   Text(855, 0, '858'),
#   Text(856, 0, '859'),
#   Text(857, 0, '860'),
#   Text(858, 0, '861'),
#   Text(859, 0, '862'),
#   Text(860, 0, '863'),
#   Text(861, 0, '864'),
#   Text(862, 0, '865'),
#   Text(863, 0, '866'),
#   Text(864, 0, '867'),
#   Text(865, 0, '868'),
#   Text(866, 0, '869'),
#   Text(867, 0, '870'),
#   Text(868, 0, '871'),
#   Text(869, 0, '872'),
#   Text(870, 0, '873'),
#   Text(871, 0, '874'),
#   Text(872, 0, '875'),
#   Text(873, 0, '876'),
#   Text(874, 0, '877'),
#   Text(875, 0, '878'),
#   Text(876, 0, '879'),
#   Text(877, 0, '880'),
#   Text(878, 0, '881'),
#   Text(879, 0, '882'),
#   Text(880, 0, '883'),
#   Text(881, 0, '884'),
#   Text(882, 0, '885'),
#   Text(883, 0, '886'),
#   Text(884, 0, '887'),
#   Text(885, 0, '888'),
#   Text(886, 0, '889'),
#   Text(887, 0, '890'),
#   Text(888, 0, '891'),
#   Text(889, 0, '892'),
#   Text(890, 0, '893'),
#   Text(891, 0, '894'),
#   Text(892, 0, '895'),
#   Text(893, 0, '896'),
#   Text(894, 0, '897'),
#   Text(895, 0, '898'),
#   Text(896, 0, '899'),
#   Text(897, 0, '900'),
#   Text(898, 0, '901'),
#   Text(899, 0, '902'),
#   Text(900, 0, '903'),
#   Text(901, 0, '904'),
#   Text(902, 0, '905'),
#   Text(903, 0, '906'),
#   Text(904, 0, '907'),
#   Text(905, 0, '908'),
#   Text(906, 0, '909'),
#   Text(907, 0, '911'),
#   Text(908, 0, '912'),
#   Text(909, 0, '913'),
#   Text(910, 0, '914'),
#   Text(911, 0, '915'),
#   Text(912, 0, '916'),
#   Text(913, 0, '917'),
#   Text(914, 0, '918'),
#   Text(915, 0, '919'),
#   Text(916, 0, '921'),
#   Text(917, 0, '922'),
#   Text(918, 0, '923'),
#   Text(919, 0, '924'),
#   Text(920, 0, '925'),
#   Text(921, 0, '926'),
#   Text(922, 0, '927'),
#   Text(923, 0, '928'),
#   Text(924, 0, '929'),
#   Text(925, 0, '930'),
#   Text(926, 0, '931'),
#   Text(927, 0, '932'),
#   Text(928, 0, '933'),
#   Text(929, 0, '934'),
#   Text(930, 0, '935'),
#   Text(931, 0, '936'),
#   Text(932, 0, '937'),
#   Text(933, 0, '938'),
#   Text(934, 0, '939'),
#   Text(935, 0, '940'),
#   Text(936, 0, '941'),
#   Text(937, 0, '942'),
#   Text(938, 0, '943'),
#   Text(939, 0, '944'),
#   Text(940, 0, '945'),
#   Text(941, 0, '946'),
#   Text(942, 0, '947'),
#   Text(943, 0, '948'),
#   Text(944, 0, '950'),
#   Text(945, 0, '951'),
#   Text(946, 0, '952'),
#   Text(947, 0, '953'),
#   Text(948, 0, '954'),
#   Text(949, 0, '955'),
#   Text(950, 0, '956'),
#   Text(951, 0, '957'),
#   Text(952, 0, '959'),
#   Text(953, 0, '960'),
#   Text(954, 0, '961'),
#   Text(955, 0, '962'),
#   Text(956, 0, '963'),
#   Text(957, 0, '964'),
#   Text(958, 0, '965'),
#   Text(959, 0, '966'),
#   Text(960, 0, '967'),
#   Text(961, 0, '968'),
#   Text(962, 0, '969'),
#   Text(963, 0, '971'),
#   Text(964, 0, '972'),
#   Text(965, 0, '973'),
#   Text(966, 0, '974'),
#   Text(967, 0, '975'),
#   Text(968, 0, '976'),
#   Text(969, 0, '977'),
#   Text(970, 0, '978'),
#   Text(971, 0, '979'),
#   Text(972, 0, '980'),
#   Text(973, 0, '981'),
#   Text(974, 0, '982'),
#   Text(975, 0, '983'),
#   Text(976, 0, '984'),
#   Text(977, 0, '985'),
#   Text(978, 0, '986'),
#   Text(979, 0, '987'),
#   Text(980, 0, '989'),
#   Text(981, 0, '990'),
#   Text(982, 0, '991'),
#   Text(983, 0, '992'),
#   Text(984, 0, '993'),
#   Text(985, 0, '994'),
#   Text(986, 0, '995'),
#   Text(987, 0, '996'),
#   Text(988, 0, '997'),
#   Text(989, 0, '998'),
#   Text(990, 0, '999'),
#   Text(991, 0, '1000'),
#   Text(992, 0, '1001'),
#   Text(993, 0, '1002'),
#   Text(994, 0, '1003'),
#   Text(995, 0, '1004'),
#   Text(996, 0, '1005'),
#   Text(997, 0, '1006'),
#   Text(998, 0, '1007'),
#   Text(999, 0, '1008'),
#   ...])

# %%
sortedstink.plot.scatter(0,1,loglog=True)
plt.title('depth per nt')
plt.xlabel('log(depth)')
plt.ylabel('log(# occurrences)')
plt.axvline(x=20, color = 'red')
plt.axvline(x=200, color = 'green')
plt.savefig('/Users/pfb2024/Lola-seq/figs/depthpernt_ATACseq.png')

# %%
data.hist(column=3,range=[0,100],bins=50)
plt.axvline(x=20, color = 'red')
plt.title('histogram of depths')
plt.savefig('/Users/pfb2024/Lola-seq/figs/histogramofdepths_ATACseq.png')

# %%
data2=pd.read_csv('/Users/pfb2024/Lola-seq/ma8_test_bg.txt',sep='\t',header=None)

# %%
data2['length']=data2[2]-data2[1]

# %%
data2.hist(column='length',range=[0,1000],bins=50,)
plt.axvline(x=100, color = 'red')
plt.title('histogram of peak lengths')
plt.savefig('/Users/pfb2024/Lola-seq/figs/histogramofpeaklengths_ATACseq.png')

# %%
#exportgraphtopdf
